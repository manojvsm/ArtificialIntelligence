# %%
import pandas as pd

# %%
dataset = pd.read_csv("50_Startups.csv")

# %%
dataset = pd.get_dummies(dataset, dtype = int, drop_first= True)

# %%
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_Florida', 'State_New York'],
#       dtype='object')

# %%
independent = dataset[['R&D Spend', 'Administration', 'Marketing Spend', 'State_Florida', 'State_New York']]

# %%
dependent = dataset[['Profit']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(independent, dependent)

# %%
#x_train, x_test, y_train, y_test

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='squared_error', splitter='best', max_depth=None)
#regressor.fit(x_train, y_train)

# r2_score => 0.8273283741503337

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='friedman_mse', splitter='best', max_depth=None)
#regressor.fit(x_train, y_train)

#r2_score => 0.9297682395024035

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='absolute_error', splitter='best', max_depth=None)
#regressor.fit(x_train, y_train)

#r2_score => 0.9251591595741854

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='poisson', splitter='best', max_depth=None)
#regressor.fit(x_train, y_train)

#r2_score => 0.589412505877888

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='poisson', splitter='random', max_depth=None, max_features = 1)
#regressor.fit(x_train, y_train)

# %%
import matplotlib.pyplot as plt
from sklearn import tree
tree.plot_tree(regressor)
plt.show()

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8692824286247256
