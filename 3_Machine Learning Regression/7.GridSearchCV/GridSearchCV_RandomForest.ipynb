# %%
import pandas as pd

# %%
datasets = pd.read_csv("insurance_pre.csv")

# %%
datasets = pd.get_dummies(datasets, dtype = int,drop_first = True)

# %%
datasets.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = datasets[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = datasets['charges']

# %%
#No need to split the data sets as x_train, y_train, x_test, y_test
#Because we use here as GridSearchCV (CV - Cross Validation)
#Cross validation to all spliting for the datasets

# %%
from sklearn.model_selection import GridSearchCV 

from sklearn.ensemble import RandomForestRegressor

estimator = RandomForestRegressor()

param_grid = {
    'n_estimators': [100, 200],#, 300, 1000, 2000, 3000],
    'criterion': ['squared_error', 'absolute_error'],#, 'friedman_mse', 'poisson'],
    'max_features': ['sqrt', 'log2', None],
    'min_samples_split': [1, 2]#, 3, 4, 5]
}

model = GridSearchCV(estimator, param_grid, refit = True)

model
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_split': [1, 2],
#                          'n_estimators': [100, 200]})

# %%
model.fit(independent, dependent)
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
# ...

# %%
model.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
result = model.cv_results_

# %%
pd.DataFrame.from_dict(result)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004770      0.003228         0.000000        0.000000
# 1        0.002882      0.000549         0.000000        0.000000
# 2        0.549751      0.149375         0.032458        0.010983
# 3        1.774092      0.990303         0.149693        0.136024
# 4        0.001839      0.000351         0.000000        0.000000
# 5        0.001776      0.000231         0.000000        0.000000
# 6        0.924628      0.230700         0.129439        0.068421
# 7        1.237356      0.106587         0.069281        0.004711
# 8        0.001952      0.000430         0.000000        0.000000
# 9        0.001805      0.000191         0.000000        0.000000
# 10       0.845914      0.154254         0.032069        0.003185
# 11       1.623145      0.365486         0.071892        0.031467
# 12       0.001828      0.000108         0.000000        0.000000
# ...

# %%
age = int(input("Age: "))
bmi = float(input("BMI: "))
children = int(input("Children: "))
sex = bool(input("Sex Male 1 or 0: "))
smoker = bool(input("Smoker 1 or 0: "))
# Out:
# Age:  20
# BMI:  16
# Children:  0
# Sex Male 1 or 0:  1
# Smoker 1 or 0:  1

# %%
prediction = model.predict([[age, bmi, children, sex, smoker]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
print ("Predict Insurance Amount: {}".format(prediction))
# Out:
# Predict Insurance Amount: [15491.2108655]
