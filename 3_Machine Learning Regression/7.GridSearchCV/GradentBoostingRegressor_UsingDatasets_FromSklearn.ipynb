# %%
from sklearn import datasets

# %%
dataset = datasets.load_diabetes()

# %%
independent = dataset.data

# %%
dependent = dataset.target

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size = 0.3, random_state = 17)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model = GradientBoostingRegressor()

# %%
model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 45.32653867230558

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 3318.9733625722706

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4167365331484768

# %%
param_grid = {
    'n_estimators': [10, 200, 300],
    'learning_rate': [0.1, 0.2, 0.3],
    'max_depth': [3, 5, 6],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3]
}

# %%
#To pass the different params and then validate the data

# %%
from sklearn.model_selection import GridSearchCV

# %%
gbr_cv = GridSearchCV(model, param_grid, cv = 3, n_jobs = -1, scoring = 'r2')

# %%
gbr_cv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.2, 0.3],
#                          'max_depth': [3, 5, 6], 'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [10, 200, 300]},
#              scoring='r2')

# %%
y_pred = gbr_cv.predict(x_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 44.861139358964905

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2967.118289048142

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4785701749388188

# %%
#To Find the best params

# %%
gbr_cv.best_params_
# Out:
# {'learning_rate': 0.2,
#  'max_depth': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
gbr_cv.best_estimator_
# Out:
# GradientBoostingRegressor(learning_rate=0.2, min_samples_leaf=3,
#                           n_estimators=10)
