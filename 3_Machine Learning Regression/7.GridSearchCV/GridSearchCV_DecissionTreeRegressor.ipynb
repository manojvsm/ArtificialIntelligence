# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset = pd.get_dummies(dataset, drop_first = True, dtype = int)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size = 0.3)

# %%
param_grids = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'splitter': ['best', 'random'],
    'max_depth': [1,2,3,4,5],
    'min_impurity_decrease': [0.0, 0.1, 0.2, 0.5]
}

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
gsv = GridSearchCV(model, param_grids, refit = True, verbose = 3, n_jobs = -1)

# %%
gsv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 160 candidates, totalling 800 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'min_impurity_decrease': [0.0, 0.1, 0.2, 0.5],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
y_predict = gsv.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
result = r2_score(y_test, y_predict)
print (gsv.best_params_ , result)
# Out:
# {'criterion': 'friedman_mse', 'max_depth': 5, 'min_impurity_decrease': 0.2, 'splitter': 'best'} 0.9982970688265344

# %%
#To display in table format

# %%
re = gsv.cv_results_

# %%
pd.DataFrame.from_dict(re)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.023978      0.022503         0.007161        0.001015
# 1         0.009607      0.001281         0.010404        0.005312
# 2         0.011212      0.002436         0.006651        0.001043
# 3         0.008943      0.001577         0.007689        0.001363
# 4         0.010097      0.001941         0.008198        0.002592
# ..             ...           ...              ...             ...
# 155       0.018711      0.011926         0.014452        0.008555
# 156       0.026181      0.014637         0.010917        0.002704
# 157       0.015628      0.006858         0.012488        0.005394
# 158       0.012336      0.003297         0.008507        0.003401
# 159       0.010706      0.002872         0.011712        0.006768
#
#     param_criterion  param_max_depth  param_min_impurity_decrease  \
# 0     squared_error                1                          0.0
# 1     squared_error                1                          0.0
# 2     squared_error                1                          0.1
# 3     squared_error                1                          0.1
# 4     squared_error                1                          0.2
# ..              ...              ...                          ...
# 155         poisson                5                          0.1
# 156         poisson                5                          0.2
# 157         poisson                5                          0.2
# 158         poisson                5                          0.5
# 159         poisson                5                          0.5
#
#     param_splitter                                             params  \
# 0             best  {'criterion': 'squared_error', 'max_depth': 1,...
# 1           random  {'criterion': 'squared_error', 'max_depth': 1,...
# 2             best  {'criterion': 'squared_error', 'max_depth': 1,...
# 3           random  {'criterion': 'squared_error', 'max_depth': 1,...
# 4             best  {'criterion': 'squared_error', 'max_depth': 1,...
# ..             ...                                                ...
# 155         random  {'criterion': 'poisson', 'max_depth': 5, 'min_...
# 156           best  {'criterion': 'poisson', 'max_depth': 5, 'min_...
# 157         random  {'criterion': 'poisson', 'max_depth': 5, 'min_...
# 158           best  {'criterion': 'poisson', 'max_depth': 5, 'min_...
# 159         random  {'criterion': 'poisson', 'max_depth': 5, 'min_...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.758507           0.711646           0.744230
# 1             0.720062           0.599442           0.744090
# 2             0.758507           0.711646           0.744230
# 3             0.582273           0.654031           0.683546
# 4             0.758507           0.711646           0.744230
# ..                 ...                ...                ...
# 155           0.987761           0.985009           0.981778
# 156           0.997889           0.996270           0.998456
# 157           0.991384           0.961754           0.967432
# 158           0.997788           0.996114           0.997960
# 159           0.956391           0.966547           0.984225
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0             0.771314           0.759480         0.749036        0.020573
# 1             0.665600           0.769896         0.699818        0.060872
# 2             0.771314           0.759480         0.749036        0.020573
# 3             0.665600           0.731074         0.663305        0.048290
# 4             0.771314           0.759480         0.749036        0.020573
# ..                 ...                ...              ...             ...
# 155           0.990592           0.985930         0.986214        0.002925
# 156           0.997948           0.997940         0.997701        0.000744
# 157           0.976429           0.980643         0.975528        0.010331
# 158           0.997358           0.997814         0.997407        0.000677
# 159           0.979892           0.979128         0.973237        0.010279
#
#      rank_test_score
# 0                129
# 1                145
# 2                135
# 3                149
# 4                129
# ..               ...
# 155               33
# 156                9
# 157               51
# 158               16
# 159               54
#
# [160 rows x 17 columns]

# %%
#To Find the best params

# %%
gsv.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 5,
#  'min_impurity_decrease': 0.2,
#  'splitter': 'best'}

# %%
gsv.best_estimator_
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=5,
#                       min_impurity_decrease=0.2)
